# %% [markdown]
# ## Data import

# %%
import pandas as pd 
import numpy as np
  
allTopSongs = pd.concat( 
    map(pd.read_csv, ['2010.csv', '2011.csv', '2012.csv','2013.csv','2014.csv','2015.csv','2016.csv','2017.csv','2018.csv','2019.csv']), ignore_index=True)
allTopSongs.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
allTopSongs.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# 1              Eminem  detroit hip hop  2010   87    93    75  -5    52   64
# 2               Kesha        dance pop  2010  120    84    76  -3    29   71
# 3           Lady Gaga        dance pop  2010  119    92    70  -4     8   71
# 4          Bruno Mars              pop  2010  109    84    64  -5     9   43
# ..                ...              ...   ...  ...   ...   ...  ..   ...  ...
# 598       Mark Ronson        dance pop  2019  104    66    61  -7    20   16
# 599        Ed Sheeran              pop  2019   95    79    75  -6     7   61
# 600         DJ Khaled        dance pop  2019  136    76    53  -5     9   65
# 601       Mark Ronson        dance pop  2019  114    79    60  -6    42   24
# 602  The Chainsmokers       electropop  2019  150    44    70  -9    13   23
#
#      dur  acous  spch  pop
# 0    217     19     4   83
# 1    263     24    23   82
# 2    200     10    14   80
# 3    295      0     4   79
# 4    221      2     4   78
# ..   ...    ...   ...  ...
# 598  176      1     3   75
# 599  206     21    12   75
# 600  260      7    34   70
# 601  217      1     7   69
# 602  213      6     6   67
#
# [603 rows x 15 columns]>

# %% [markdown]
# *looks like data is in the right format

# %%
# Most popular song in dataset
allTopSongs["pop"].describe()
# Out:
# count    603.000000
# mean      66.520730
# std       14.517746
# min        0.000000
# 25%       60.000000
# 50%       69.000000
# 75%       76.000000
# max       99.000000
# Name: pop, dtype: float64

# %%
allTopSongs[allTopSongs["pop"]== 99]
# Out:
#      Unnamed: 0     title    artist top genre  year  bpm  nrgy  dnce  dB  \
# 572         573  Memories  Maroon 5       pop  2019   91    32    76  -7
#
#      live  val  dur  acous  spch  pop
# 572     8   57  189     84     5   99

# %% [markdown]
# The most popular song is Maroon 5's - Memories (🤮)

# %% [markdown]
# ## What Artist Has the most songs in the dataset?

# %%
allTopSongs['artist'].value_counts(ascending=False).head(10)
# Out:
# artist
# Katy Perry          17
# Justin Bieber       16
# Rihanna             15
# Maroon 5            15
# Lady Gaga           14
# Bruno Mars          13
# Shawn Mendes        11
# Pitbull             11
# Ed Sheeran          11
# The Chainsmokers    11
# Name: count, dtype: int64

# %% [markdown]
# As we can see the most represented artist on the charts in the 2010s is Katy Perry

# %% [markdown]
# ## What is the most popular Genre of Music

# %%
allTopSongs['top genre'].value_counts(ascending=False).head(10)
# Out:
# top genre
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# Name: count, dtype: int64

# %% [markdown]
# As we can see the top genre is dance pop

# %% [markdown]
# ## Are there any songs in the dataset more than once?

# %%
len(allTopSongs['title'].unique()) ==len(allTopSongs)
len(allTopSongs['title'].unique()), len(allTopSongs)
# Out:
# (584, 603)

# %% [markdown]
# apparently we have some duplicates

# %%
allTopSongs[allTopSongs['title'].duplicated() == True]
# Out:
#      Unnamed: 0                                            title  \
# 54           55                             Just the Way You Are
# 64           65                                        Marry You
# 93           94         Written in the Stars (feat. Eric Turner)
# 95           96          Castle Walls (feat. Christina Aguilera)
# 152         153          We Are Never Ever Getting Back Together
# 239         240  A Little Party Never Killed Nobody (All We Got)
# 295         296                                            Hello
# 322         323                                            Sugar
# 363         364                                        The Hills
# 364         365                                    Love Yourself
# 378         379                                         Stitches
# 396         397                                          Company
# 403         404                            Runnin' (Lose It All)
# 404         405                                             Here
# 473         474                                        All I Ask
# 510         511                                        I Like It
# 541         542                                    Say Something
# 548         549                                       First Time
# 557         558                                Kissing Strangers
#
#                 artist                  top genre  year  bpm  nrgy  dnce  dB  \
# 54          Bruno Mars                        pop  2011  109    84    64  -5
# 64          Bruno Mars                        pop  2011  145    83    62  -5
# 93        Tinie Tempah                  dance pop  2011   91    95    64  -4
# 95                T.I.                atl hip hop  2011   80    86    45  -5
# 152       Taylor Swift                        pop  2013   86    68    63  -6
# 239             Fergie                  dance pop  2014  130    62    76  -6
# 295              Adele               british soul  2015  158    45    48  -6
# 322           Maroon 5                        pop  2015  120    79    75  -7
# 363         The Weeknd  canadian contemporary r&b  2016  113    56    58  -7
# 364      Justin Bieber               canadian pop  2016  100    38    61 -10
# 378       Shawn Mendes               canadian pop  2016  150    75    75  -7
# 396      Justin Bieber               canadian pop  2016   95    80    59  -5
# 403        Naughty Boy             tropical house  2016  139    85    32  -6
# 404       Alessia Cara  canadian contemporary r&b  2016  120    82    38  -4
# 473              Adele               british soul  2017  142    28    59  -5
# 510            Cardi B                        pop  2018  136    73    82  -4
# 541  Justin Timberlake                  dance pop  2018   97    63    71  -7
# 548               Kygo                        edm  2018   90    59    63  -7
# 557               DNCE                  dance pop  2018  120    74    77  -6
#
#      live  val  dur  acous  spch  pop
# 54      9   43  221      2     4   78
# 64     10   48  230     33     4   73
# 93     18   57  220      6     7   52
# 95     26   58  329      7    39   49
# 152    12   75  193      1     9   75
# 239     9   52  241      1    18   65
# 295     9   29  295     34     3   73
# 322     9   88  235      6     3   66
# 363    14   14  242      7     5   84
# 364    28   52  234     84    44   83
# 378     5   76  207      2     7   78
# 396     8   43  208     13     6   72
# 403    48    8  213      1     8   69
# 404     8   33  199      8    10   68
# 473    15   34  272     88     3   71
# 510    37   65  253     10    13   85
# 541     8   37  279     10     8   74
# 548    10   68  194     20    11   71
# 557     9   86  202      5     4   66

# %%
len(allTopSongs[allTopSongs['title'].duplicated() == True]) + len(allTopSongs['title'].unique())
# Out:
# 603

# %%
allTopSongs[allTopSongs['title'] == 'Kissing Strangers']
# Out:
#      Unnamed: 0              title artist  top genre  year  bpm  nrgy  dnce  \
# 488         489  Kissing Strangers   DNCE  dance pop  2017  120    74    77
# 557         558  Kissing Strangers   DNCE  dance pop  2018  120    74    77
#
#      dB  live  val  dur  acous  spch  pop
# 488  -6     9   86  202      5     4   66
# 557  -6     9   86  202      5     4   66

# %% [markdown]
# Ah, if a song was on the chart for consecutive years it creates a duplicate.

# %% [markdown]
# ## Is there a relationship between popularity and danceability?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme('paper')
sns.regplot(x="dnce", y="pop", data=allTopSongs, fit_reg=True)

plt.xlabel('Danceability')
plt.ylabel('Popularity')
 
# title of plot
pvalues = []
plt.title('Popularity vs Danceability')
# Out:
# Text(0.5, 1.0, 'Popularity vs Danceability')

# %% [markdown]
# ## Does having a higher bpm lead to having a higher energy score?

# %%
sns.set_theme('paper')
sns.regplot(x="bpm", y="nrgy", data=allTopSongs, fit_reg=True)

plt.xlabel('BPM')
plt.ylabel('Energy')
 
# title of plot
plt.title('Plot 2')
plt.show()
#correlation table of all numeric data https://www.geeksforgeeks.org/python-pandas-dataframe-corr/?ref=lbp
allTopSongs.corr(method="kendall", min_periods=1, numeric_only=True)
# Out:
#             Unnamed: 0      year       bpm      nrgy      dnce        dB  \
# Unnamed: 0    1.000000  0.944546 -0.122474 -0.164710  0.048187 -0.134594
# year          0.944546  1.000000 -0.128420 -0.182723  0.055205 -0.144439
# bpm          -0.122474 -0.128420  1.000000  0.102325 -0.051299  0.065510
# nrgy         -0.164710 -0.182723  0.102325  1.000000  0.013137  0.497097
# dnce          0.048187  0.055205 -0.051299  0.013137  1.000000  0.060009
# dB           -0.134594 -0.144439  0.065510  0.497097  0.060009  1.000000
# live         -0.082032 -0.088911  0.066216  0.096634 -0.066970  0.043083
# val          -0.090550 -0.092497  0.017899  0.255942  0.343812  0.242089
# dur          -0.156871 -0.163490  0.015644 -0.094295 -0.121874 -0.124413
# acous         0.126532  0.139477 -0.110011 -0.241768 -0.073123 -0.123650
# spch          0.048536  0.050134  0.041797  0.151545  0.064370  0.045656
# pop           0.079454  0.196696 -0.026585 -0.103318  0.077166 -0.035759
#
#                 live       val       dur     acous      spch       pop
# Unnamed: 0 -0.082032 -0.090550 -0.156871  0.126532  0.048536  0.079454
# year       -0.088911 -0.092497 -0.163490  0.139477  0.050134  0.196696
# bpm         0.066216  0.017899  0.015644 -0.110011  0.041797 -0.026585
# nrgy        0.096634  0.255942 -0.094295 -0.241768  0.151545 -0.103318
# dnce       -0.066970  0.343812 -0.121874 -0.073123  0.064370  0.077166
# dB          0.043083  0.242089 -0.124413 -0.123650  0.045656 -0.035759
# live        1.000000 -0.034799  0.044754 -0.038161  0.089546 -0.065181
# val        -0.034799  1.000000 -0.178299 -0.124259  0.130241  0.013065
# dur         0.044754 -0.178299  1.000000  0.029160 -0.059357 -0.053854
# acous      -0.038161 -0.124259  0.029160  1.000000 -0.018791  0.078429
# spch        0.089546  0.130241 -0.059357 -0.018791  1.000000 -0.014202
# pop        -0.065181  0.013065 -0.053854  0.078429 -0.014202  1.000000

# %% [markdown]
# If BPM were causally implicated in Energy score I wouldn't expect such vertical variation for any particular BPM.  If almost all BPMs are have a range of energy scores from about 40-90 and there is mild correlation between the two variables, that leads me to concluded that BPM is not causally producing Energy score, but there is a relationship between the two.  If there is a causal i.e. functional relationship between BPM and Energy score I would expect it to be multivariate - including more than one variable to predict energy score with greater accuracy.  For example, while the correlation between bpm and nrgy is .1023, the correlation between spch and nrgy is .1515 which suggests it is more important a factor in determining energy score.  Still I would posit a causal relationship for either.

# %%
allTopSongs.sort_values(by=['nrgy','top genre'], ascending=False)
# Out:
#      Unnamed: 0                             title             artist  \
# 198         199                          Pom Poms     Jonas Brothers
# 50           51                             Hello     Martin Solveig
# 134         135  Don't Stop the Party (feat. TJR)            Pitbull
# 181         182                       Rock N Roll      Avril Lavigne
# 24           25               All The Right Moves        OneRepublic
# ..          ...                               ...                ...
# 436         437     Beautiful Birds (feat. Birdy)          Passenger
# 249         250                     Say Something  A Great Big World
# 255         256                  Not About Angels              Birdy
# 431         432                             Start        John Legend
# 442         443                 Million Years Ago              Adele
#
#         top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 198      boy band  2013  148    98    68  -2    28   90  198      7     9   52
# 50       big room  2010  128    98    67  -3    10   45  191      1     3    0
# 134     dance pop  2012  127    96    72  -4    38   95  206      1     9   59
# 181  canadian pop  2013  184    96    47  -3    34   67  207      1    13   61
# 24      dance pop  2010  146    95    53  -4    28   65  238     26     5   65
# ..            ...   ...  ...   ...   ...  ..   ...  ...  ...    ...   ...  ...
# 436      folk-pop  2016   86    17    39 -13    11   14  214     91     3   36
# 249    neo mellow  2014  138    15    45  -9     9    9  229     87     3   61
# 255    neo mellow  2014  116    14    41 -10     9   23  190     97     4   56
# 431    neo mellow  2016  110     4    52 -15     9   26  310     99     4   47
# 442  british soul  2016    0     0     0 -60     0    0  227      0     0    0
#
# [603 rows x 15 columns]

# %% [markdown]
# Its a tie between "Boy Band" and "Big Room"

# %% [markdown]
# ## What percentage of songs may have been recorded live?
# (Consider anything above 50 in the live column to be recorded live)

# %%
f'{len(allTopSongs[allTopSongs['live']>50])/len(allTopSongs)*100}%'
# Out:
# '2.9850746268656714%'

# %% [markdown]
# ## What percentage of songs may have been recorded acoustic?

# %%
f'{len(allTopSongs[allTopSongs['acous']>50])/len(allTopSongs)*100}%'
# Out:
# '7.2968490878938645%'

# %% [markdown]
# ## Which year’s songs have the highest amount of spoken word in the song?

# %%
speechByYear=pd.pivot_table(allTopSongs, values='spch', index=['year'], aggfunc='sum')
sns.set_theme('paper')
speechByYearAverage = pd.pivot_table(allTopSongs, values='spch', index=['year'])
plt.xlabel('Year')
plt.ylabel('Cumulative Speech Scores')
plt.title('Total Speechiness by Year')
sns.lineplot(data=speechByYear)
plt.show()
plt.xlabel('Year')
plt.ylabel('Average Speech Scores')
plt.title('Average Speechiness by Year')
sns.lineplot(data=speechByYearAverage)
plt.show()
# Out:
# /Users/johnmunger/tth_data_analysis/project_5/.conda/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/johnmunger/tth_data_analysis/project_5/.conda/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/johnmunger/tth_data_analysis/project_5/.conda/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/johnmunger/tth_data_analysis/project_5/.conda/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
speechByYear, speechByYearAverage
# Out:
# (      spch
#  year
#  2010   453
#  2011   512
#  2012   203
#  2013   590
#  2014   503
#  2015   670
#  2016   669
#  2017   636
#  2018   552
#  2019   252,
#            spch
#  year
#  2010  8.882353
#  2011  9.660377
#  2012  5.800000
#  2013  8.309859
#  2014  8.672414
#  2015  7.052632
#  2016  8.362500
#  2017  9.784615
#  2018  8.625000
#  2019  8.129032)

# %% [markdown]
# In my opinion, the speechiest year is the 2017.  While the cumulative score isn't the highest, it is near the highest, and the average speechiness of each song is highest that year.  As always the answer depends specificially about the intent of the question.  But these charts illuminate the relationship between speechiness and the year.
